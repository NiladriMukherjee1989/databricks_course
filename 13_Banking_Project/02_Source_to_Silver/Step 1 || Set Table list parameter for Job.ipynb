# %%
tables_df=spark.table("banking.metadata.tables").drop("created_at")
new_rows= tables_df.collect()
#since new_list is a Sprak row object, it needs to be converted into a clean list to be able to pass to the taskValues()
new_dict=[row.asDict() for row in new_rows]
dbutils.jobs.taskValues.set(key="pass_dict", value=new_dict)
