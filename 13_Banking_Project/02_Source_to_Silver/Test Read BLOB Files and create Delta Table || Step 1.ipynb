# %%
table_df=spark.sql("select table_name,source_system,source_schema,source_path from banking.metadata.tables where source_system='blob'")
table_dict=table_df.toPandas().to_dict(orient='records')
print(table_dict)
dbutils.jobs.taskValues.set("Pass_List",table_dict)
