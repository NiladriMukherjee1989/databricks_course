# %%
tables_df=spark.table("banking.metadata.tables")
new_list= tables_df.collect()
table_list=[i["table_name"] for i in new_list]
print(table_list)
dbutils.jobs.taskValues.set(key="table_list", value=table_list)
