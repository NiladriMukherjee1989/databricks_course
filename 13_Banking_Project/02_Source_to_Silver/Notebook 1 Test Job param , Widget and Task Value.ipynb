# %%
dbutils.widgets.text("source_schema","")
schema_val=dbutils.widgets.get("source_schema")
print(f"The job parameter for source_schema is : {schema_val}")
#Now I will pass this as a task value so the pipeline can see it in the next task. I will use Databricks native taskValues() function :
dbutils.jobs.taskValues.set(key="schema_name",value=schema_val)
