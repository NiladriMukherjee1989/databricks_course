# %%
status="Calling the notebook now"
notebook_to_execute=f"../../13_Banking_Project/02_Source_to_Silver/Test Read BLOB Files and create Delta Table || Step 3"

try :
    result_cnt=dbutils.notebook.run(notebook_to_execute,0)
    if result_cnt :
        result_cnt=int(result_cnt)
        print(f"Calling notebook was successful, count returned as : {result_cnt}")
        status="Calling notebook was successful"
    
except Exception as e:
    status="Calling notebook failed"
    print("Calling notebook failed")
